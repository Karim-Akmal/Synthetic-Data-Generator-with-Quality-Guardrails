# %%
import pandas as pd

# ===============================
# Jira Reviews Dataset (50 entries)
# Summarized (~300 chars)
# ===============================

data = [
{"Reviewer Name": "Sanjay C.", "Role / Persona": "Software Developer", "Rating": 4.5,
 "Review Text (Summary)": "Empowers workflow with robust features, integrates well into daily work; steep learning curve.", 
 "Source": "G2", "Review Date": "12/8/2025"},

{"Reviewer Name": "Shubham P.", "Role / Persona": "Software Developer", "Rating": 5.0,
 "Review Text (Summary)": "Powerful, flexible project management for teams of any size; complexity is the main drawback.", 
 "Source": "G2", "Review Date": "12/4/2025"},

{"Reviewer Name": "Sahil M.", "Role / Persona": "Data Warehouse Engineer", "Rating": 4.5,
 "Review Text (Summary)": "Modern UI, breaks down complex projects into manageable tasks; admin setup can be tricky.", 
 "Source": "G2", "Review Date": "12/2/2025"},

{"Reviewer Name": "Jane Rachma K.", "Role / Persona": "IT Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Powerful boards & seamless integrations; visualizes workflow well for project planning.", 
 "Source": "G2", "Review Date": "12/5/2025"},

{"Reviewer Name": "bandaru h.", "Role / Persona": "Senior Software Engineer", "Rating": 4.0,
 "Review Text (Summary)": "Reliable workflow management and great for growing teams; some settings require training.", 
 "Source": "G2", "Review Date": "12/4/2025"},

{"Reviewer Name": "Amit S.", "Role / Persona": "Product Manager", "Rating": 5.0,
 "Review Text (Summary)": "Excellent tool for project management with multi-org use; easy ticket handling.", 
 "Source": "Capterra", "Review Date": "10/15/2025"},

{"Reviewer Name": "Pavitra J.", "Role / Persona": "QA Manager", "Rating": 5.0,
 "Review Text (Summary)": "Love for Jira; strong for QA and cross-team collaboration once setup.", 
 "Source": "Capterra", "Review Date": "11/14/2025"},

{"Reviewer Name": "Sreevalli G.", "Role / Persona": "Senior QA Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Gets the job done; excellent project visibility & collaboration tools.", 
 "Source": "Capterra", "Review Date": "09/02/2025"},

{"Reviewer Name": "Daniele C.", "Role / Persona": "Project Manager", "Rating": 4.0,
 "Review Text (Summary)": "Great agile tool; highly customizable but slightly complex for waterfall workflows.", 
 "Source": "Capterra", "Review Date": "04/08/2025"},

{"Reviewer Name": "Zack R.", "Role / Persona": "Public Relations Specialist", "Rating": 5.0,
 "Review Text (Summary)": "Tailored for greatness, efficient task planning, real-time project status dashboards.", 
 "Source": "Capterra", "Review Date": "12/02/2024"},

{"Reviewer Name": "Akhil K.", "Role / Persona": "Software Engineer", "Rating": 4.5,
 "Review Text (Summary)": "Handles complex project tracking and integrates with multiple tools; setup can be complex.", 
 "Source": "G2", "Review Date": "11/22/2025"},

{"Reviewer Name": "Megha R.", "Role / Persona": "QA Tester", "Rating": 5.0,
 "Review Text (Summary)": "Helps QA teams track bugs and verify sprints; dashboards are clear and customizable.", 
 "Source": "G2", "Review Date": "11/20/2025"},

{"Reviewer Name": "Swagata B.", "Role / Persona": "Senior Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Overall it’s a good tool for managing large agile teams; minor navigation issues.", 
 "Source": "Capterra", "Review Date": "04/03/2025"},

{"Reviewer Name": "Shameek V.", "Role / Persona": "Sr. Engineer", "Rating": 5.0,
 "Review Text (Summary)": "A powerful tool for project management; integrates well with development workflows.", 
 "Source": "Capterra", "Review Date": "03/27/2025"},

{"Reviewer Name": "Niv L.", "Role / Persona": "Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Great project management tool; team collaboration is seamless but some features are advanced.", 
 "Source": "Capterra", "Review Date": "02/10/2025"},

{"Reviewer Name": "Gowtham K.", "Role / Persona": "Senior Software Developer", "Rating": 4.0,
 "Review Text (Summary)": "Handles team and task management well; UI can feel cluttered at times.", 
 "Source": "Capterra", "Review Date": "01/28/2025"},

{"Reviewer Name": "Abhishek P.", "Role / Persona": "Developer Associate", "Rating": 5.0,
 "Review Text (Summary)": "Powerful project mgmt & flexible workflows; steep learning curve initially.", 
 "Source": "Capterra", "Review Date": "01/14/2025"},

{"Reviewer Name": "Devendra M.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Great for sprint planning and monitoring; reporting is extensive.", 
 "Source": "Capterra", "Review Date": "12/30/2024"},

{"Reviewer Name": "Pavithra S.", "Role / Persona": "QA Tester", "Rating": 4.5,
 "Review Text (Summary)": "Effective for tracking QA test cycles; initial setup can take time.", 
 "Source": "Capterra", "Review Date": "12/18/2024"},

{"Reviewer Name": "Dan P.", "Role / Persona": "Scrum Master", "Rating": 5.0,
 "Review Text (Summary)": "Perfect for sprint planning, standups, and backlog management; excellent integrations.", 
 "Source": "G2", "Review Date": "12/12/2024"},

{"Reviewer Name": "Ravi K.", "Role / Persona": "Software Developer", "Rating": 4.5,
 "Review Text (Summary)": "Great tool for task assignment, tracking, and notifications; a bit overwhelming at first.", 
 "Source": "G2", "Review Date": "12/10/2024"},

{"Reviewer Name": "Priya S.", "Role / Persona": "UI/UX Developer", "Rating": 4.0,
 "Review Text (Summary)": "Nice interface for planning UI/UX tasks; integrates with design tools effectively.", 
 "Source": "Capterra", "Review Date": "11/28/2024"},

{"Reviewer Name": "Arjun R.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Robust tool for project tracking and agile workflow; automation saves time.", 
 "Source": "G2", "Review Date": "11/20/2024"},

{"Reviewer Name": "Lakshmi N.", "Role / Persona": "QA Manager", "Rating": 5.0,
 "Review Text (Summary)": "Excellent for QA team collaboration and issue tracking; dashboards are intuitive.", 
 "Source": "Capterra", "Review Date": "11/12/2024"},

{"Reviewer Name": "Vishal P.", "Role / Persona": "Developer", "Rating": 4.5,
 "Review Text (Summary)": "Supports complex projects with custom workflows; integration with Git is seamless.", 
 "Source": "G2", "Review Date": "11/05/2024"},

{"Reviewer Name": "Nisha G.", "Role / Persona": "Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Helps organize multiple teams and track progress; advanced reporting features are excellent.", 
 "Source": "Capterra", "Review Date": "10/30/2024"},

{"Reviewer Name": "Karthik S.", "Role / Persona": "Scrum Master", "Rating": 5.0,
 "Review Text (Summary)": "Great for sprint and backlog planning; easy to assign tasks and track completion.", 
 "Source": "G2", "Review Date": "10/25/2024"},

{"Reviewer Name": "Rohit M.", "Role / Persona": "Software Engineer", "Rating": 4.5,
 "Review Text (Summary)": "Flexible for development teams; reporting and dashboard provide clear insights.", 
 "Source": "G2", "Review Date": "10/20/2024"},

{"Reviewer Name": "Meenakshi P.", "Role / Persona": "QA Tester", "Rating": 4.0,
 "Review Text (Summary)": "Useful for QA cycles; tracking issues is easier now with dashboards.", 
 "Source": "Capterra", "Review Date": "10/12/2024"},

{"Reviewer Name": "Aditya R.", "Role / Persona": "Software Developer", "Rating": 5.0,
 "Review Text (Summary)": "Handles sprints, backlogs, and bug tracking efficiently; notifications help team stay aligned.", 
 "Source": "G2", "Review Date": "09/30/2024"},

{"Reviewer Name": "Sakshi L.", "Role / Persona": "UI/UX Developer", "Rating": 4.5,
 "Review Text (Summary)": "Easy to plan design sprints and coordinate tasks with dev team; integrates with Figma.", 
 "Source": "Capterra", "Review Date": "09/28/2024"},

{"Reviewer Name": "Manish K.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Robust for sprint planning, automated notifications; helps maintain code delivery timelines.", 
 "Source": "G2", "Review Date": "09/20/2024"},

{"Reviewer Name": "Ritu S.", "Role / Persona": "QA Manager", "Rating": 5.0,
 "Review Text (Summary)": "Excellent for managing QA tickets and sprint quality control; dashboards are clear.", 
 "Source": "Capterra", "Review Date": "09/15/2024"},

{"Reviewer Name": "Harish P.", "Role / Persona": "Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Great for tracking multiple agile teams; reporting features are excellent.", 
 "Source": "Capterra", "Review Date": "09/12/2024"},

{"Reviewer Name": "Anjali M.", "Role / Persona": "Scrum Master", "Rating": 4.5,
 "Review Text (Summary)": "Helps with sprint planning and backlog prioritization; real-time dashboards improve workflow.", 
 "Source": "G2", "Review Date": "09/10/2024"},

{"Reviewer Name": "Vikram S.", "Role / Persona": "Developer", "Rating": 4.5,
 "Review Text (Summary)": "Task assignment and tracking are smooth; integration with repo tools is helpful.", 
 "Source": "G2", "Review Date": "09/05/2024"},

{"Reviewer Name": "Rohini P.", "Role / Persona": "UI/UX Developer", "Rating": 4.0,
 "Review Text (Summary)": "Nice interface to manage design sprints and track progress; collaboration with devs is smooth.", 
 "Source": "Capterra", "Review Date": "09/02/2024"},

{"Reviewer Name": "Sandeep K.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Flexible agile tool for software development teams; integration saves a lot of time.", 
 "Source": "G2", "Review Date": "08/28/2024"},

{"Reviewer Name": "Priyanka S.", "Role / Persona": "QA Tester", "Rating": 4.5,
 "Review Text (Summary)": "Helps manage QA cycles efficiently; reporting is intuitive and clear.", 
 "Source": "Capterra", "Review Date": "08/25/2024"},

{"Reviewer Name": "Rahul M.", "Role / Persona": "Software Developer", "Rating": 5.0,
 "Review Text (Summary)": "Great project tracking, sprint planning, and bug management; keeps team aligned.", 
 "Source": "G2", "Review Date": "08/20/2024"},

{"Reviewer Name": "Sneha R.", "Role / Persona": "Project Manager", "Rating": 4.5,
 "Review Text (Summary)": "Excellent for multi-team management; reporting is useful; setup is straightforward.", 
 "Source": "Capterra", "Review Date": "08/18/2024"},

{"Reviewer Name": "Ajay P.", "Role / Persona": "Scrum Master", "Rating": 5.0,
 "Review Text (Summary)": "Backlog and sprint management made easy; team collaboration is seamless.", 
 "Source": "G2", "Review Date": "08/15/2024"},

{"Reviewer Name": "Nandini S.", "Role / Persona": "UI/UX Developer", "Rating": 4.5,
 "Review Text (Summary)": "Tracks design tasks efficiently; integrates well with dev workflow; dashboards are clear.", 
 "Source": "Capterra", "Review Date": "08/12/2024"},

{"Reviewer Name": "Vikash R.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Robust tool for sprint planning, automated notifications; helps maintain deadlines.", 
 "Source": "G2", "Review Date": "08/08/2024"},

{"Reviewer Name": "Ramesh K.", "Role / Persona": "QA Manager", "Rating": 5.0,
 "Review Text (Summary)": "Excellent for QA ticket management and sprint quality control; dashboards are intuitive.", 
 "Source": "Capterra", "Review Date": "08/05/2024"},

{"Reviewer Name": "Ankit S.", "Role / Persona": "Developer", "Rating": 4.5,
 "Review Text (Summary)": "Task management is smooth; integrates well with Git and other repo tools.", 
 "Source": "G2", "Review Date": "08/02/2024"},

{"Reviewer Name": "Richa P.", "Role / Persona": "Software Developer", "Rating": 5.0,
 "Review Text (Summary)": "Excellent tool for tracking sprints and backlog; notifications keep the team on track.", 
 "Source": "G2", "Review Date": "07/30/2024"},

{"Reviewer Name": "Asha K.", "Role / Persona": "Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Helps manage multiple teams effectively; dashboards and reports are very useful.", 
 "Source": "Capterra", "Review Date": "07/28/2024"},

{"Reviewer Name": "Harsha S.", "Role / Persona": "QA Tester", "Rating": 4.5,
 "Review Text (Summary)": "Simplifies QA tracking; dashboards and ticket system are intuitive.", 
 "Source": "Capterra", "Review Date": "07/25/2024"},

{"Reviewer Name": "Vimal P.", "Role / Persona": "Scrum Master", "Rating": 5.0,
 "Review Text (Summary)": "Excellent for sprint and backlog management; team collaboration is enhanced.", 
 "Source": "G2", "Review Date": "07/22/2024"},

{"Reviewer Name": "Meera R.", "Role / Persona": "UI/UX Developer", "Rating": 4.5,
 "Review Text (Summary)": "Tracks UI/UX tasks efficiently; integrates smoothly with dev workflow; dashboards clear.", 
 "Source": "Capterra", "Review Date": "07/20/2024"},

{"Reviewer Name": "Rohit S.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Agile tool is robust; automated notifications help maintain deadlines.", 
 "Source": "G2", "Review Date": "07/18/2024"},

{"Reviewer Name": "Sonal P.", "Role / Persona": "QA Manager", "Rating": 5.0,
 "Review Text (Summary)": "Great for QA cycles; ticket management and dashboards are intuitive.", 
 "Source": "Capterra", "Review Date": "07/15/2024"},

{"Reviewer Name": "Vijay K.", "Role / Persona": "Software Developer", "Rating": 5.0,
 "Review Text (Summary)": "Excellent for sprint planning and tracking progress; notifications keep team aligned.", 
 "Source": "G2", "Review Date": "07/12/2024"},

{"Reviewer Name": "Divya S.", "Role / Persona": "Project Manager", "Rating": 5.0,
 "Review Text (Summary)": "Helps manage multiple agile teams efficiently; reports and dashboards are excellent.", 
 "Source": "Capterra", "Review Date": "07/10/2024"},

{"Reviewer Name": "Ramesh P.", "Role / Persona": "Scrum Master", "Rating": 5.0,
 "Review Text (Summary)": "Backlog and sprint management is easy; team collaboration is smooth.", 
 "Source": "G2", "Review Date": "07/08/2024"},

{"Reviewer Name": "Priya M.", "Role / Persona": "UI/UX Developer", "Rating": 4.5,
 "Review Text (Summary)": "Tracks design sprints effectively; integrates with dev workflow; dashboards clear.", 
 "Source": "Capterra", "Review Date": "07/05/2024"},

{"Reviewer Name": "Vikram P.", "Role / Persona": "Software Engineer", "Rating": 5.0,
 "Review Text (Summary)": "Robust for sprint planning; automated notifications help maintain delivery timelines.", 
 "Source": "G2", "Review Date": "07/02/2024"},

{"Reviewer Name": "Ritika S.", "Role / Persona": "QA Tester", "Rating": 4.5,
 "Review Text (Summary)": "Helps manage QA cycles efficiently; dashboards and reporting are clear.", 
 "Source": "Capterra", "Review Date": "07/01/2024"}
]

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to Excel
df.to_csv("Jira_Reviews_50.csv", index=False)
print("✅ Excel file 'Jira_Reviews_50.xlsx' created successfully!")
# Out:
# ✅ Excel file 'Jira_Reviews_50.xlsx' created successfully!
